# %% [markdown]
# # Correlation Turn-in activity Lesson1
# ## Compute correlations and create matrix to examine correlations in the given power_lifing_dataset.

# %%
# Import Packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weights = pd.read_csv('C:/Users/chris/Desktop/data/DS105/Lesson1/power_lifting.csv')

# %%
weights.head()
# Out:
#    MeetID              Name Sex   Equipment   Age     Division  BodyweightKg
# 0       0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49         59.60  \
# 1       0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44         58.51
# 2       0       Dawn Bogart   F  Single-ply  42.0  Open Senior         58.51
# 3       0       Dawn Bogart   F         Raw  42.0  Open Senior         58.51
# 4       0      Destiny Dula   F         Raw  18.0   Teen 18-19         63.68
#
#   WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg  Deadlift4Kg
# 0            60       NaN        47.63       NaN        20.41          NaN  \
# 1            60       NaN       142.88       NaN        95.25          NaN
# 2            60       NaN       142.88       NaN        95.25          NaN
# 3            60       NaN          NaN       NaN        95.25          NaN
# 4          67.5       NaN          NaN       NaN        31.75          NaN
#
#    BestDeadliftKg  TotalKg Place   Wilks
# ...

# %%
# Drop Categorgical Data for Correlation test
weights1 = weights.drop(['MeetID','Name', 'Equipment', 'Division','Sex','WeightClassKg', 'Place'], axis = 1)

# %%
weights1.head()
# Out:
#     Age  BodyweightKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg
# 0  47.0         59.60       NaN        47.63       NaN        20.41  \
# 1  42.0         58.51       NaN       142.88       NaN        95.25
# 2  42.0         58.51       NaN       142.88       NaN        95.25
# 3  42.0         58.51       NaN          NaN       NaN        95.25
# 4  18.0         63.68       NaN          NaN       NaN        31.75
#
#    Deadlift4Kg  BestDeadliftKg  TotalKg   Wilks
# 0          NaN           70.31   138.35  155.05
# 1          NaN          163.29   401.42  456.38
# 2          NaN          163.29   401.42  456.38
# 3          NaN             NaN    95.25  108.29
# 4          NaN           90.72   122.47  130.47

# %%
weights1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386414 entries, 0 to 386413
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Age             147147 non-null  float64
#  1   BodyweightKg    384012 non-null  float64
#  2   Squat4Kg        1243 non-null    float64
#  3   BestSquatKg     298071 non-null  float64
#  4   Bench4Kg        1962 non-null    float64
#  5   BestBenchKg     356364 non-null  float64
#  6   Deadlift4Kg     2800 non-null    float64
#  7   BestDeadliftKg  317847 non-null  float64
#  8   TotalKg         363237 non-null  float64
#  9   Wilks           362194 non-null  float64
# dtypes: float64(10)
# memory usage: 29.5 MB

# %%
# Create matrix using SNS
sns.heatmap(weights1.corr(), annot=True)
# Out:
# <AxesSubplot: >
